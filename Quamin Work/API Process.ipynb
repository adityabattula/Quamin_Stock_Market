# %%
pip install alpha_vantage

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.fundamentaldata import FundamentalData

API_key = '4QNVMIRCG3Q0Z8Y4'

ts = TimeSeries(key=API_key, output_format='pandas')
data = ts.get_intraday('IBM', interval='5min')

# %%
data[0]
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2024-09-06 19:55:00   200.73   200.73  200.60    200.60       16.0
# 2024-09-06 19:50:00   200.73   200.73  200.73    200.73       25.0
# 2024-09-06 19:45:00   200.00   200.70  199.77    200.70      131.0
# 2024-09-06 19:40:00   199.76   199.76  199.76    199.76        1.0
# 2024-09-06 19:35:00   199.76   199.76  199.76    199.76       10.0
# ...                      ...      ...     ...       ...        ...
# 2024-09-06 11:00:00   200.75   202.09  200.75    201.23    32320.0
# 2024-09-06 10:55:00   200.98   201.07  200.70    200.79    29327.0
# 2024-09-06 10:50:00   201.52   201.62  200.84    200.93    40603.0
# 2024-09-06 10:45:00   201.35   201.66  201.31    201.53    30330.0
# 2024-09-06 10:40:00   201.74   201.90  201.26    201.34    23907.0
#
# [100 rows x 5 columns]

# %%
key = '4QNVMIRCG3Q0Z8Y4'
fd = FundamentalData(key,output_format = 'pandas')

data = fd.get_income_statement_annual('IBM')
data[0]
# Out:
#                               fiscalDateEnding reportedCurrency  grossProfit  \
# date
# 1970-01-01 00:00:00.000000000       2023-12-31              USD  34300000000
# 1970-01-01 00:00:00.000000001       2022-12-31              USD  32687000000
# 1970-01-01 00:00:00.000000002       2021-12-31              USD  31486000000
# 1970-01-01 00:00:00.000000003       2020-12-31              USD  30865000000
# 1970-01-01 00:00:00.000000004       2019-12-31              USD  31533000000
# 1970-01-01 00:00:00.000000005       2018-12-31              USD  36936000000
# 1970-01-01 00:00:00.000000006       2017-12-31              USD  36943000000
# 1970-01-01 00:00:00.000000007       2016-12-31              USD  38516000000
# 1970-01-01 00:00:00.000000008       2015-12-31              USD  40684000000
# 1970-01-01 00:00:00.000000009       2014-12-31              USD  46407000000
# 1970-01-01 00:00:00.000000010       2013-12-31              USD  48684000000
# ...

# %%
import requests
import pandas as pd


url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=IBM&apikey=4QNVMIRCG3Q0Z8Y4'
r = requests.get(url)
data = r.json()

dataframe = pd.DataFrame.from_dict(data)
import pandas as pd
pd.set_option('display.max_columns', None)

print(dataframe.head(1))
# Out:
#   items                         sentiment_score_definition  \
# 0    50  x <= -0.35: Bearish; -0.35 < x <= -0.15: Somew...
#
#                           relevance_score_definition  \
# 0  0 < x <= 1, with a higher score indicating hig...
#
#                                                 feed
# 0  {'title': 'Where Will IBM Be in 5 Years?', 'ur...
